# %%
class Parant:
    def __init__(self):
        pass

    def hello(self):
        print("หวัดดีครัช/แค่ะ")

# %%
class Child(Parant):
    def __init__(self):
        pass
        
    def hello(self):
        print("สวัสดีครับ/ค่ะ")

# %%
c1 = Child()
c1.hello()
# Out:
# สวัสดีครับ/ค่ะ
